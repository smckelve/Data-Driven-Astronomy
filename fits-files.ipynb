# %%
from astropy.io import fits
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import numpy as np

fits_file = fits.open('ngc1261.fits')
fits_file.info()
# Out:
# Filename: ngc1261.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     123   (1200, 1200)   float32

# %%
image_data = fits_file[0].data
np.shape(image_data)
#print(image_data)
# Out:
# (1200, 1200)

# %%
plt.figure()
plt.imshow(image_data, origin = 'lower', norm = LogNorm(), cmap = 'Greys')
plt.colorbar()
plt.show()

# %%
section1 = image_data[350:850, 350:850]

plt.figure()
plt.imshow(section1, origin = 'lower', norm = LogNorm(), cmap = 'Greys')
plt.colorbar()
plt.show()
